# %% [markdown]
# <a href="https://colab.research.google.com/github/svetajamkina/PYTHON/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data import

# %%
import seaborn as sns
import pandas as pd

titanic_data = sns.load_dataset('titanic')
titanic_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #Data Investigation

# %%
titanic_data.isnull().sum() #checking the 0 values
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# embark_town    0
# dtype: int64

# %%
titanic_data.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# embark_town     object
# dtype: object

# %%
#titanic_data.drop('deck', axis=1, inplace=True) # a lot empty values
titanic_data.drop(['alive', 'alone', 'adult_male'], axis=1, inplace=True) #a lot of empty values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-4c0f6b208e28> in <cell line: 2>()
#       1 #titanic_data.drop('deck', axis=1, inplace=True) # a lot empty values
# ----> 2 titanic_data.drop(['alive', 'alone', 'adult_male'], axis=1, inplace=True) #a lot of empty values
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# ...

# %% [markdown]
# #Data transformation

# %%
titanic_data['class'] = titanic_data['class'].astype(str) #modified the object from category to str
titanic_data.fillna(0, inplace=True) #replaces empty with null

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  embark_town
# 0    man  Southampton
# 1  woman    Cherbourg
# 2  woman  Southampton
# 3  woman  Southampton
# 4    man  Southampton

# %%
# Sex column
sex_mapping = {'male': 0, 'female': 1}
titanic_data['sex'] = titanic_data['sex'].map(sex_mapping)

# %%
# Embark town
titanic_data['embark_town'].unique()
embark_town_mapping = {'Southampton': 1, 'Cherbourg': 2, 'Queenstown': 3, 0:0 }
titanic_data['embark_town']= titanic_data['embark_town'].map(embark_town_mapping)

# %%
# Embarked
titanic_data['embarked'].unique()
embarked_mapping = {'S':1, 'C':2, 'Q':3, 0:0}
titanic_data['embarked'] = titanic_data['embarked'].map(embarked_mapping)

# %%
# Who
titanic_data['who'].unique()
who_mapping = {'man':1, 'woman':2, 'child':3}
titanic_data['who'] = titanic_data['who'].map(who_mapping)

# %%
titanic_data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 0         0       3    0  22.0      1      0   7.2500         1  Third    1
# 1         1       1    1  38.0      1      0  71.2833         2  First    2
# 2         1       3    1  26.0      0      0   7.9250         1  Third    2
# 3         1       1    1  35.0      1      0  53.1000         1  First    2
# 4         0       3    0  35.0      0      0   8.0500         1  Third    1
#
#    embark_town
# 0            1
# 1            2
# 2            1
# 3            1
# 4            1

# %%
titanic_data.info() #checj, what type we have , and no 0
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    int64
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    int64
#  8   class        891 non-null    object
#  9   who          891 non-null    int64
#  10  embark_town  891 non-null    int64
# dtypes: float64(2), int64(8), object(1)
# memory usage: 76.7+ KB

# %% [markdown]
# #LabelEncoder

# %% [markdown]
# #Data modeling

# %%
from sklearn.model_selection import train_test_split

X = titanic_data.drop('survived', axis=1) #FEATURES
y = titanic_data['survived'] #DEPENDENT VARIABLE

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

# %% [markdown]
# #LogicalRegression

# %%
from sklearn.linear_model import LogisticRegression #import

# %%
model = LogisticRegression() #initialize

# %%
model.fit(X_train, y_train) #train
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-22bcef7fdcc0> in <cell line: 1>()
# ----> 1 model.fit(X_train, y_train) #train
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1206             _dtype = [np.float64, np.float32]
#    1207
# -> 1208         X, y = self._validate_data(
#    1209             X,
#    1210             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
# ...

# %%
prediction_results = model.predict(X_test)
prediction_results
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-d1d6b420bbb3> in <cell line: 1>()
# ----> 1 prediction_results = model.predict(X_test)
#       2 prediction_results
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     449         """
#     450         xp, _ = get_namespace(X)
# --> 451         scores = self.decision_function(X)
#     452         if len(scores.shape) == 1:
#     453             indices = xp.astype(scores > 0, int)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     430         xp, _ = get_namespace(X)
#     431
# --> 432         X = self._validate_data(X, accept_sparse="csr", reset=False)
#     433         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
# ...
